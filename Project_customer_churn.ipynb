# %%
#1. Data Manipulation.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/MyDrive/customer_churn (1).csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
#a. Extract the 5th column and store it in 'customer_5'
customer_5 = data.iloc[:4] #access the 5th column with the help of indexes
customer_5.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# ...

# %%
customer_5 = data.loc[:,["Dependents"]]
customer_5.head()
# Out:
#   Dependents
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No

# %%
#b. Extract the 15th column and store it in "customer_15"

customer_15 = data.iloc[:,14]
customer_15.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: StreamingMovies, dtype: object

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#c. Extract all the male senior citizens whose payment method is electronic check and store the result in "senior_male_electronic"

senior_male_electronic = data[(data['gender']=='Male')&(data['SeniorCitizen']==1)&(data['PaymentMethod']=='Electronic check')]
senior_male_electronic.head()
# Out:
#     customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20  8779-QRDMV   Male              1      No         No       1           No
# 55  1658-BYGOY   Male              1      No         No      18          Yes
# 57  5067-XJQFU   Male              1     Yes        Yes      66          Yes
# 78  0191-ZHSKZ   Male              1      No         No      30          Yes
# 91  2424-WVHPL   Male              1      No         No       1          Yes
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 20  No phone service             DSL             No  ...              Yes
# 55               Yes     Fiber optic             No  ...               No
# 57               Yes     Fiber optic             No  ...              Yes
# 78                No             DSL            Yes  ...               No
# 91                No     Fiber optic             No  ...               No
#
# ...

# %%
senior_male_electronic.shape
# Out:
# (298, 21)

# %%
#d. Extract all those customers whose tenure is greater than 70 months or their Monthly charges is more than 100$ and store the result in 'customer_total_tenure'
#tenure>70 or monthlycharges>100

customer_total_tenure = data[(data['tenure']>70)|(data['MonthlyCharges']>100)]
customer_total_tenure.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 8            Yes     Fiber optic             No  ...              Yes
# 12           Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
# 14            No     Fiber optic            Yes  ...              Yes
# 15           Yes     Fiber optic            Yes  ...              Yes
#
# ...

# %%
customer_total_tenure.shape
# Out:
# (1259, 21)

# %%
#e. Extract all the customers whose Contract is of two years, payment method is mailed
# Check and the value of the churm is 'Yes' and then store it in 'two_mail_yes'

two_mail_yes = data[(data['Contract']=='Two year')&(data['PaymentMethod']== 'Mailed check')&(data['Churn']=='Yes')]
two_mail_yes.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
two_mail_yes.shape
# Out:
# (3, 21)

# %%
#f. Extract 333 random records from the cutomer_churn dataframe and store the result in 'customer_333'

customer_333 = data.sample(n=333)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1203  9087-EYCPR  Female              0      No         No      60
# 1449  6806-YDEUL  Female              1      No         No       6
# 3052  5151-HQRDG    Male              0     Yes         No      37
# 5770  6252-DFGTK  Female              0     Yes         No      37
# 2991  2207-QPJED  Female              1     Yes         No      37
# ...          ...     ...            ...     ...        ...     ...
# 6017  4482-FTFFX    Male              0      No         No       5
# 6822  5389-FFVKB    Male              1     Yes         No      32
# 2971  9348-ROUAI  Female              0     Yes        Yes      59
# 2718  7274-CGTOD    Male              0      No         No      62
# 3799  2930-UOTMB  Female              0      No         No      31
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1203          Yes               Yes              No  No internet service  ...
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#g. Get the count of different level from the 'churn' column

data['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
data['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
data['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
# In the similar way you can find out all the remaining columns

# %%
#2. Data Visualization.

# %%
# Build a bar-plot for the 'InternetService' column:

#a. Set X-axis label to 'Categaries of Internet Service'
#b. Set y-axis label to 'Count of Categaries'
#c. Set the tittle of the plot to be 'Distribution of Internet Series'
#d. Set the color of the bars as 'Orange'

# %%
x=data['InternetService'].value_counts().keys().tolist()
y=data['InternetService'].value_counts().tolist()
plt.bar(x,y,color='orange')
plt.xlabel("Categaries of the Internet Services")
plt.ylabel("Count of Categories")
plt.title("Distribution of the Internet Service")
# Out:
# Text(0.5, 1.0, 'Distribution of the Internet Service')

# %%
#Build a histogram for the 'tenure' column:

#a. Set the number of bins to be 30
#b. Set the color of the bins to be 'green'
#c. Assign the title 'Distribution of tenure'

# %%
plt.hist(data['tenure'],color='green',bins=30)
plt.title('Distribution of tenure')
# Out:
# Text(0.5, 1.0, 'Distribution of tenure')

# %%
#Build a scatter-plot between ‘MonthlyCharges’ and ‘tenure’. Map 'MonthlyCharges' to the y-axis and 'tenure' to the x-axis:

 #a. Assign the points a color of ‘brown’
 #b. Set the x-axis label to ‘Tenure of customer’
 #c. Set the y-axis label to ‘Monthly Charges of customer’
 #d. Set the title to ‘Tenure vs Monthly Charges’
 #e. Build a box-plot between ‘tenure’ & ‘Contract’. Map ‘tenure’ on the
 #y-axis &
 #f. ‘Contract’ on the x-axis.

# %%
plt.figure(figsize=(15,10))
x = data['tenure'].tolist()
y = data['MonthlyCharges'].tolist()
plt.scatter(x,y,color='brown')
plt.xlabel('tenure of the customer')
plt.ylabel('Monthly Charges of the customer')
plt.title('Tenure vs Monthly Charges')
data.boxplot(column='tenure',by='Contract')
plt.show()

# %%
#3. Linear Regression:

# %%
# Build a simple linear model where dependent variable is ‘MonthlyCharges’and independent variable is ‘tenure’:

 #a. Divide the dataset into train and test sets in 70:30 ratio.
 #b. Build the model on train set and predict the values on test set
 #c. After predicting the values, find the root mean square error
 #d. Find out the error in prediction & store the result in ‘error’
 #e. Find the root mean square error

# %%
from sklearn import linear_model #import the needed package to execute
from sklearn.model_selection import train_test_split

# %%
x=pd.DataFrame(data['tenure']) #independant variable
y=pd.DataFrame(data['MonthlyCharges']) #dependant variable

# %%
x
# Out:
#       tenure
# 0          1
# 1         34
# 2          2
# 3         45
# 4          2
# ...      ...
# 7038      24
# 7039      72
# 7040      11
# 7041       4
# 7042      66
#
# [7043 rows x 1 columns]

# %%
y
# Out:
#       MonthlyCharges
# 0              29.85
# 1              56.95
# 2              53.85
# 3              42.30
# 4              70.70
# ...              ...
# 7038           84.80
# 7039          103.20
# 7040           29.60
# 7041           74.40
# 7042          105.65
#
# [7043 rows x 1 columns]

# %%
#split the data inoto train and test

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.shape
# Out:
# (4930, 1)

# %%
x_test.shape
# Out:
# (2113, 1)

# %%
y_train.shape
# Out:
# (4930, 1)

# %%
y_test.shape
# Out:
# (2113, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

# %%
regressor.fit(x_train,y_train) #.fit() fits the variables that you need to train for your linear rtegression model, only the train variables will be fitted over here
# Out:
# LinearRegression()

# %%
#predict the value
y_pred = regressor.predict(x_test) #y_pred is storing the predicted value in it from the results of the x_test variable

# %%
y_pred #predicted values
# Out:
# array([[60.95089608],
#        [72.98096699],
#        [59.1903979 ],
#        ...,
#        [75.62171426],
#        [70.63363608],
#        [65.6455579 ]])

# %%
y_test #actual value
# Out:
#       MonthlyCharges
# 2200           58.20
# 4627          116.60
# 3225           71.95
# 2828           20.45
# 3768           77.75
# ...              ...
# 4448           99.70
# 1231           64.40
# 3304          109.95
# 4805           24.55
# 5843           81.60
#
# [2113 rows x 1 columns]

# %%
#RMSE/Accuracy score

from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
rmse
# Out:
# 29.394584027273893

# %%
 #4. Logistic Regression:

# %%
# Build a simple logistic regression model where dependent variable is 'Churn' and independent variable is ‘MonthlyCharges’:
 #a. Divide the dataset in 65:35 ratio
 #b. Build the model on train set and predict the values on test set
 #c. Build the confusion matrix and get the accuracy score
 #d. Build a multiple logistic regression model where dependent variable is ‘Churn’ and independent variables are ‘tenure’ and ‘MonthlyCharges’
 #e. Divide the dataset in 80:20 ratio
 #f. Build the model on train set and predict the values on test set
 #g. Build the confusion matrix and get the accuracy score

# %%
# simple logistic regression:

import pandas as pd
x = pd.DataFrame(data.loc[:,['MonthlyCharges']]) #independant variables
y = pd.DataFrame(data.loc[:,['Churn']]) #dependant variables

# %%
#split the variable
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.35, random_state=0)

# %%
#train the model

from sklearn.linear_model import LogisticRegression
logic=LogisticRegression()
logic.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
#predicted value

y_pred=logic.predict(x_test)
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1815,    0],
#        [ 651,    0]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7360097323600974

# %%
#d Multiple logistic regression.

import pandas as pd
x=pd.DataFrame(data.loc[:,['MonthlyCharges','tenure']]) #independant variables
y=pd.DataFrame(data['Churn']) #dependant variables

# %%
# split the variables

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=0)

# %%
# train the model

from sklearn.linear_model import LogisticRegression
logic=LogisticRegression()
logic.fit(x_train,y_train)  #.fit() fits the variables that you need to train for your linear rtegression model, only the train variables will be fitted over here
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
#predicted value

y_pred=logic.predict(x_test)
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
y_test
# Out:
#      Churn
# 2200    No
# 4627    No
# 3225    No
# 2828    No
# 3768    No
# ...    ...
# 5753    No
# 4109   Yes
# 4106   Yes
# 2760    No
# 2534    No
#
# [2466 rows x 1 columns]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1634,  181],
#        [ 364,  287]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7789943227899432

# %%
#5. Decision trees:

# %%
# Build a decision tree model where dependent variable is ‘Churn’ and independent variable is ‘tenure’:
 #a. Divide the dataset in 80:20 ratio
 #b. Build the model on train set and predict the values on test set
 #c. Build the confusion matrix and calculate the accuracy

# %%
x=pd.DataFrame(data['tenure']) #independant variable
y=pd.DataFrame(data['Churn']) #depemndant variable

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
d_t=DecisionTreeClassifier()
d_t.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=d_t.predict(x_test)
y_pred #predicted value
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'Yes'], dtype=object)

# %%
y_test
# Out:
#      Churn
# 2200    No
# 4627    No
# 3225    No
# 2828    No
# 3768    No
# ...    ...
# 2631   Yes
# 5333   Yes
# 6972   Yes
# 4598    No
# 3065    No
#
# [1409 rows x 1 columns]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[965,  76],
#        [281,  87]])

# %%
#6.Random Forest:

# %%
 #Build a Random Forest model where dependent variable is ‘Churn’ and independent variables are ‘tenure’ and ‘MonthlyCharges’:
 #a. Divide the dataset in 70:30 ratio
 #b. Build the model on train set and predict the values on test set
 #c. Build the confusion matrix and calculate the accuracy

# %%
x=pd.DataFrame(data.loc[:,['tenure','MonthlyCharges']]) #indepandant variable
y=pd.DataFrame(data['Churn']) #dependant variable

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
R_f=RandomForestClassifier(n_estimators=100)

# %%
R_f.fit(x_train,y_train)
# Out:
# <ipython-input-116-8fc0389ae8f6>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   R_f.fit(x_train,y_train)
# RandomForestClassifier()

# %%
y_pred=R_f.predict(x_test)
y_pred #predicted value
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
y_test
# Out:
#      Churn
# 2200    No
# 4627    No
# 3225    No
# 2828    No
# 3768    No
# ...    ...
# 4448   Yes
# 1231    No
# 3304    No
# 4805    No
# 5843    No
#
# [2113 rows x 1 columns]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1343,  217],
#        [ 319,  234]])
